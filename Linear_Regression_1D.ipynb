# %% [markdown]
# <a href="https://colab.research.google.com/github/viniolimpio3/AI-Classes/blob/main/Linear_Regression_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Regressão Linear - 1D

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Base de Dados

# %%
X = [0,0.12,0.25,0.27,0.38,0.42,0.44,0.55,0.92,1.0] #features
Y = [0,0.15,0.54,0.51,0.34,0.1,0.19,0.53,1.0,0.58] #target

plt.scatter(X,Y)
plt.ylabel('Y')
plt.xlabel('X')
plt.show()

# %% [markdown]
# ### Regressão Linear

# %% [markdown]
# Modelo Matemático:
#
# $x \rightarrow{}$ feature
#
# $y \rightarrow{}$ target
#
# $\hat{y_{i}} = w_1x_{i}+w_0$ $\rightarrow{}$ target estimado pela equação da reta
#
# $Erro(i) = (\hat{y_{i}}-y_{i})^{2} \rightarrow{}$ erro gerado para cada linha da base de dados
#
# $Custo(\hat{y_{i}})= Custo(w_{1}, w_{0}) = \frac{1}{N}\sum_{i=1}^{N}(\hat{y_{i}}-y_{i})^{2} \rightarrow{}$ função custo para cada equação da reta considerada
#
# $\frac{\partial (Custo)}{\partial w_{1}} = \frac{\partial (Custo)}{\partial \hat{y_{i}}} \frac{\partial \hat{y_{i}}}{\partial w_{1}}  = \frac{2}{N}\sum_{i=1}^{N}(\hat{y_{i}}-y_{i})x_{i} \rightarrow{}$ derivada parcial da função custo em relação ao parâmetro $w_{1}$ da equação da reta
#
# $\frac{\partial (Custo)}{\partial w_{0}} = \frac{\partial (Custo)}{\partial \hat{y_{i}}} \frac{\partial \hat{y_{i}}}{\partial w_{0}}  = \frac{2}{N}\sum_{i=1}^{N}(\hat{y_{i}}-y_{i}) \rightarrow{}$ derivada parcial da função custo em relação ao parâmetro $w_{0}$ da equação da reta
#
# $\frac{\partial (Custo)}{\partial w_{1}} = 0 \rightarrow$ ponto de mínimo da função custo em relação ao parâmtero $w_{1}$
#
# $\frac{\partial (Custo)}{\partial w_{0}} = 0 \rightarrow$ ponto de mínimo da função custo em relação ao parâmtero $w_{0}$

# %% [markdown]
# Modelo computacional:
#
# - escolher parâmetros iniciais $w_{1}$ e $w_{0}$
# - calcular $\hat{y_{i}}$ para todas as linhas da base de dados
# - calcular função $Custo(\hat{y_{i}})$
# - atualizar os parâmetros $w_{1}$ e $w_{0}$ a cada iteração, fazendo:
#     - $w_{1} \leftarrow w_{1}-\alpha \frac{\partial (Custo)}{\partial w_{1}}$
#     - $w_{0} \leftarrow w_{0}-\alpha \frac{\partial (Custo)}{\partial w_{0}}$

# %% [markdown]
# ### Machine Learning "from scratch"

# %%
#Parâmetros inicais
w1 = 0.1
w0 = 0.7 #intercept
alpha = 0.01
iteracoes = 1000
costs = []

fig, ax = plt.subplots()
ax.plot(X, np.multiply(w1, X) + w0, 'r-', label = 'Regressão inicial')
ax.legend()
plt.ylabel('Y')
plt.xlabel('X')

#Loop de iteracoes para o gradiente convergir para o valor minimo
for i in range(iteracoes):

#Função Custo
    Y_pred = np.multiply(w1, X) + w0 #y_chapeu
    Loss_error = (Y_pred - Y)**2 #Erro de cada linha da base
    cost = np.sum(Loss_error) #funcao Custo

#Gradiente
    dw0 = np.sum((Y_pred - Y))
    dw1 = np.dot((Y_pred - Y), X)
    costs.append(cost)
    w1 = w1 - alpha*dw1
    w0 = w0 - alpha*dw0

    if i == (iteracoes-1):

        print("Custo em", i,"iterações = ", cost)
        print("w1 =",w1, "w0 =", w0)
        ax.plot(X, np.multiply(w1, X) + w0, 'g-', label = 'Regressão final')
        ax.scatter(X, Y, color='blue', label = 'Valores reais')
        ax.legend(loc = 'best')
        plt.show()
# Out:
# Custo em 999 iterações =  0.3792148533270863
# w1 = 0.6763298820890978 w0 = 0.09980829212408686

# %% [markdown]
# ### Resultados

# %%
print("w1 = ", w1,"& w0 = ",  w0)
plt.plot(costs)
plt.ylabel('Custo')
plt.xlabel('Iterações')
plt.show()
# Out:
# w1 =  0.6763298820890978 & w0 =  0.09980829212408686

# %%
plt.plot(X,np.multiply(w1, X) + w0, 'red')
plt.scatter(X,Y)
plt.ylabel('Y')
plt.xlabel('X')
plt.show()

# %% [markdown]
# ### API

# %%
nova_entrada_X = 1.2

y_estimado_fs = nova_entrada_X*w1 + w0

print('O valor estimado para a entrada:', nova_entrada_X, 'é', y_estimado_fs)
# Out:
# O valor estimado para a entrada: 1.2 é 0.9114041506310042

# %% [markdown]
# ### Machine Learning com Sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
X_sk = np.array(X)
Y_sk = np.array(Y)
Y_sk.shape
# Out:
# (10,)

# %%
lm = LinearRegression()
lm.fit(X_sk.reshape(-1,1),Y_sk)
# Out:
# LinearRegression()

# %% [markdown]
# ### Resultados

# %%
print('wi, i>0: \n', lm.coef_)
print('w0: \n', lm.intercept_)
# Out:
# wi, i>0:
#  [0.67665744]
# w0:
#  0.09965401531194024

# %%
predictions = lm.predict(X_sk.reshape(-1,1))

# %%
plt.scatter(Y_sk,predictions)
plt.xlabel('Y real')
plt.ylabel('Y estimado')
# Out:
# Text(0, 0.5, 'Y estimado')

# %% [markdown]
# ### API

# %%
nova_entrada_X = 1.2

y_estimado_sk = nova_entrada_X*lm.coef_ + lm.intercept_

print(f'O valor estimado para a entrada: {nova_entrada_X} é {y_estimado_sk[0]}')
# Out:
# O valor estimado para a entrada: 1.2 é 0.9116429385893465

# %% [markdown]
# ### Comparação entre algoritmos de Regressão Linear

# %%
print(f'Valor estimado pelo algoritmo de Regressão Linear from "Scratch": {round(y_estimado_fs,6)}')
print('')
print(f'Valor estimado pelo algoritmo de Regressão Linear from "Sklearn": {round(y_estimado_sk[0],6)}')
# Out:
# Valor estimado pelo algoritmo de Regressão Linear from "Scratch": 0.911404
#
# Valor estimado pelo algoritmo de Regressão Linear from "Sklearn": 0.911643
